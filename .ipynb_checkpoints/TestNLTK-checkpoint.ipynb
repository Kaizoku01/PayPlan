# %%
import nltk
from nltk.corpus import treebank

# %%
text="Rs92.0 debited@SBI UPI frm A/cX0217 on 24May22 RefNo 214410824359. If not done by u, fwd this SMS to 9223008333/Call 1800111109 or 09449112211 to block UPI"

# %%
tokens = nltk.word_tokenize(text)

# %%
tokens = nltk.word_tokenize(text)

# %%
tokens
# Out:
# ['Rs92.0',
#  'debited',
#  '@',
#  'SBI',
#  'UPI',
#  'frm',
#  'A/cX0217',
#  'on',
#  '24May22',
#  'RefNo',
#  '214410824359',
#  '.',
#  'If',
#  'not',
#  'done',
#  'by',
#  'u',
#  ',',
#  'fwd',
#  'this',
#  'SMS',
#  'to',
#  '9223008333/Call',
#  '1800111109',
#  'or',
#  '09449112211',
#  'to',
#  'block',
#  'UPI']

# %%
tagged = nltk.pos_tag(tokens)

# %%
tagged[0:9]
# Out:
# [('Rs92.0', 'NNP'),
#  ('debited', 'VBD'),
#  ('@', 'NNP'),
#  ('SBI', 'NNP'),
#  ('UPI', 'NNP'),
#  ('frm', 'NN'),
#  ('A/cX0217', 'NNP'),
#  ('on', 'IN'),
#  ('24May22', 'CD'),
#  ('RefNo', 'NNP')]

# %%
tokens
# Out:
# ['Rs92.0',
#  'debited',
#  '@',
#  'SBI',
#  'UPI',
#  'frm',
#  'A/cX0217',
#  'on',
#  '24May22',
#  'RefNo',
#  '214410824359',
#  '.',
#  'If',
#  'not',
#  'done',
#  'by',
#  'u',
#  ',',
#  'fwd',
#  'this',
#  'SMS',
#  'to',
#  '9223008333/Call',
#  '1800111109',
#  'or',
#  '09449112211',
#  'to',
#  'block',
#  'UPI']
